# %% [markdown]
# <a href="https://colab.research.google.com/github/Rosalesmariana/Simulacion-I-/blob/main/Kolmogorov_AVANCE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tabulate import tabulate

def ordenar_numeros(lista):
    lista_ordenada = sorted(lista)
    return lista_ordenada

numeros = [0.8797, 0.3884, 0.6289, 0.8750, 0.5999, 0.8589, 0.9996,0.2415, 0.3808, 0.9606,
0.9848, 0.3469,0.7977,0.5844,0.8147,0.6431,0.7387,0.5613, 0.0318 ,0.7401,
0.4557, 0.1592, 0.8536, 0.8846, 0.3410,0.1492,0.8681,0.5291,0.3188, 0.5992,
0.9170, 0.2204,0.5991,0.5461, 0.5739 ,0.3254, 0.0856, 0.2258, 0.4603,0.5027,
0.8376, 0.6235,0.3681, 0.2088 ,0.1525, 0.2006 ,0.4720, 0.4272 ,0.6360 ,0.0954]

x_i = ordenar_numeros(numeros)
# Calcular el D+

for i=1



encabezados=["i","x_i"]
tabla = tabulate(enumerate((x_i), start=1), headers=encabezados, tablefmt="grid")
print(tabla)
# Out:
# +-----+--------+
# |   i |    x_i |
# +=====+========+
# |   1 | 0.0318 |
# +-----+--------+
# |   2 | 0.0856 |
# +-----+--------+
# |   3 | 0.0954 |
# +-----+--------+
# |   4 | 0.1492 |
# +-----+--------+
# |   5 | 0.1525 |
# +-----+--------+
# |   6 | 0.1592 |
# +-----+--------+
# |   7 | 0.2006 |
# +-----+--------+
# |   8 | 0.2088 |
# +-----+--------+
# |   9 | 0.2204 |
# +-----+--------+
# |  10 | 0.2258 |
# +-----+--------+
# |  11 | 0.2415 |
# +-----+--------+
# |  12 | 0.3188 |
# +-----+--------+
# |  13 | 0.3254 |
# +-----+--------+
# |  14 | 0.341  |
# +-----+--------+
# |  15 | 0.3469 |
# +-----+--------+
# |  16 | 0.3681 |
# +-----+--------+
# |  17 | 0.3808 |
# +-----+--------+
# |  18 | 0.3884 |
# +-----+--------+
# |  19 | 0.4272 |
# +-----+--------+
# |  20 | 0.4557 |
# +-----+--------+
# |  21 | 0.4603 |
# +-----+--------+
# |  22 | 0.472  |
# +-----+--------+
# |  23 | 0.5027 |
# +-----+--------+
# |  24 | 0.5291 |
# +-----+--------+
# |  25 | 0.5461 |
# ...
