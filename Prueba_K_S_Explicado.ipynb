# %% [markdown]
# <a href="https://colab.research.google.com/github/Rosalesmariana/Simulacion-I-/blob/main/Prueba_K_S_Explicado.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from tabulate import tabulate
from scipy.stats import kstwobign #Importamos kstwobign que está relacionada con la distribución K-S


# Datos proporcionados
datos = [0.8797, 0.3884, 0.6289, 0.8750, 0.5999, 0.8589, 0.9996, 0.2415, 0.3808, 0.9606,
         0.9848, 0.3469, 0.7977, 0.5844, 0.8147, 0.6431, 0.7387, 0.5613, 0.0318, 0.7401,
         0.4557, 0.1592, 0.8536, 0.8846, 0.3410, 0.1492, 0.8681, 0.5291, 0.3188, 0.5992,
         0.9170, 0.2204, 0.5991, 0.5461, 0.5739, 0.3254, 0.0856, 0.2258, 0.4603, 0.5027,
         0.8376, 0.6235, 0.3681, 0.2088, 0.1525, 0.2006, 0.4720, 0.4272, 0.6360, 0.0954]

# Ordenamos los datos proporcionados
datos_ordenados = np.sort(datos)

# Calculamos los valores de D+ y D-
n = len(datos_ordenados) #Asignamos a la variable "n" como el total de datos proporcionados
D_mas = [(i+1)/n - datos_ordenados[i] for i in range(n)] #Calculamos los D+
D_menos = [datos_ordenados[i] - (i)/n for i in range(n)] # Calculamos los D-

# Creamos una lista de listas para almacenar los resultados
resultados = []

# Llenamos la lista con los resultados
for i in range(n):
    fila = [i+1, datos_ordenados[i], D_mas[i], D_menos[i]]
    resultados.append(fila)

# Encontramos el máximo entre D+ y D-
D_maximo = max(max(D_mas), max(D_menos))

# Calculamos el valor crítico para alpha = 0.05 y n=50, donde alpha es el nivel de significancia y n el tamaño de la muestra
K = kstwobign.ppf(1-0.05)/np.sqrt(n)

# Mostramos los resultados en la tabla
encabezados = ["i", "x_i", "D+", "D-"]
print(tabulate(resultados, headers=encabezados, tablefmt="grid"))
print("Máximo entre D+ y D-:", D_maximo)
print("Valor crítico: ", K)
# Comparamos D con K para determinar si rechazamos o no rechazamos la hipótesis nula
if D_maximo < K:
    print("\nConclusión: Aceptamos la hipótesis nula.")
else:
    print("\nConclusión: Rechazamos la hipótesis nula.")
# Out:
# +-----+--------+---------+---------+
# |   i |    x_i |      D+ |      D- |
# +=====+========+=========+=========+
# |   1 | 0.0318 | -0.0118 |  0.0318 |
# +-----+--------+---------+---------+
# |   2 | 0.0856 | -0.0456 |  0.0656 |
# +-----+--------+---------+---------+
# |   3 | 0.0954 | -0.0354 |  0.0554 |
# +-----+--------+---------+---------+
# |   4 | 0.1492 | -0.0692 |  0.0892 |
# +-----+--------+---------+---------+
# |   5 | 0.1525 | -0.0525 |  0.0725 |
# +-----+--------+---------+---------+
# |   6 | 0.1592 | -0.0392 |  0.0592 |
# +-----+--------+---------+---------+
# |   7 | 0.2006 | -0.0606 |  0.0806 |
# +-----+--------+---------+---------+
# |   8 | 0.2088 | -0.0488 |  0.0688 |
# +-----+--------+---------+---------+
# |   9 | 0.2204 | -0.0404 |  0.0604 |
# +-----+--------+---------+---------+
# |  10 | 0.2258 | -0.0258 |  0.0458 |
# +-----+--------+---------+---------+
# |  11 | 0.2415 | -0.0215 |  0.0415 |
# +-----+--------+---------+---------+
# |  12 | 0.3188 | -0.0788 |  0.0988 |
# +-----+--------+---------+---------+
# |  13 | 0.3254 | -0.0654 |  0.0854 |
# +-----+--------+---------+---------+
# |  14 | 0.341  | -0.061  |  0.081  |
# +-----+--------+---------+---------+
# |  15 | 0.3469 | -0.0469 |  0.0669 |
# +-----+--------+---------+---------+
# |  16 | 0.3681 | -0.0481 |  0.0681 |
# +-----+--------+---------+---------+
# |  17 | 0.3808 | -0.0408 |  0.0608 |
# +-----+--------+---------+---------+
# |  18 | 0.3884 | -0.0284 |  0.0484 |
# +-----+--------+---------+---------+
# |  19 | 0.4272 | -0.0472 |  0.0672 |
# +-----+--------+---------+---------+
# |  20 | 0.4557 | -0.0557 |  0.0757 |
# +-----+--------+---------+---------+
# |  21 | 0.4603 | -0.0403 |  0.0603 |
# +-----+--------+---------+---------+
# |  22 | 0.472  | -0.032  |  0.052  |
# +-----+--------+---------+---------+
# |  23 | 0.5027 | -0.0427 |  0.0627 |
# +-----+--------+---------+---------+
# |  24 | 0.5291 | -0.0491 |  0.0691 |
# +-----+--------+---------+---------+
# |  25 | 0.5461 | -0.0461 |  0.0661 |
# +-----+--------+---------+---------+
# |  26 | 0.5613 | -0.0413 |  0.0613 |
# +-----+--------+---------+---------+
# |  27 | 0.5739 | -0.0339 |  0.0539 |
# +-----+--------+---------+---------+
# |  28 | 0.5844 | -0.0244 |  0.0444 |
# +-----+--------+---------+---------+
# |  29 | 0.5991 | -0.0191 |  0.0391 |
# +-----+--------+---------+---------+
# |  30 | 0.5992 |  0.0008 |  0.0192 |
# +-----+--------+---------+---------+
# |  31 | 0.5999 |  0.0201 | -0.0001 |
# +-----+--------+---------+---------+
# |  32 | 0.6235 |  0.0165 |  0.0035 |
# +-----+--------+---------+---------+
# |  33 | 0.6289 |  0.0311 | -0.0111 |
# +-----+--------+---------+---------+
# |  34 | 0.636  |  0.044  | -0.024  |
# +-----+--------+---------+---------+
# |  35 | 0.6431 |  0.0569 | -0.0369 |
# +-----+--------+---------+---------+
# |  36 | 0.7387 | -0.0187 |  0.0387 |
# +-----+--------+---------+---------+
# |  37 | 0.7401 | -0.0001 |  0.0201 |
# +-----+--------+---------+---------+
# |  38 | 0.7977 | -0.0377 |  0.0577 |
# +-----+--------+---------+---------+
# |  39 | 0.8147 | -0.0347 |  0.0547 |
# +-----+--------+---------+---------+
# |  40 | 0.8376 | -0.0376 |  0.0576 |
# +-----+--------+---------+---------+
# |  41 | 0.8536 | -0.0336 |  0.0536 |
# +-----+--------+---------+---------+
# |  42 | 0.8589 | -0.0189 |  0.0389 |
# +-----+--------+---------+---------+
# |  43 | 0.8681 | -0.0081 |  0.0281 |
# +-----+--------+---------+---------+
# |  44 | 0.875  |  0.005  |  0.015  |
# +-----+--------+---------+---------+
# |  45 | 0.8797 |  0.0203 | -0.0003 |
# +-----+--------+---------+---------+
# |  46 | 0.8846 |  0.0354 | -0.0154 |
# +-----+--------+---------+---------+
# |  47 | 0.917  |  0.023  | -0.003  |
# +-----+--------+---------+---------+
# |  48 | 0.9606 | -0.0006 |  0.0206 |
# +-----+--------+---------+---------+
# |  49 | 0.9848 | -0.0048 |  0.0248 |
# +-----+--------+---------+---------+
# |  50 | 0.9996 |  0.0004 |  0.0196 |
# +-----+--------+---------+---------+
# Máximo entre D+ y D-: 0.09879999999999997
# Valor crítico:  0.19206415147703973
#
# Conclusión: Aceptamos la hipótesis nula.
